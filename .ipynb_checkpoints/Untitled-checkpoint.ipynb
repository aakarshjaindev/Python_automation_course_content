# %%
# !pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    --------- ------------------------------ 2.6/11.5 MB 13.6 MB/s eta 0:00:01
#    --------------- ------------------------ 4.5/11.5 MB 10.5 MB/s eta 0:00:01
#    ------------------------------ --------- 8.7/11.5 MB 13.3 MB/s eta 0:00:01
#    ---------------------------------------  11.3/11.5 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.5/11.5 MB 12.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ----------- ---------------------------- 3.7/12.6 MB 18.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.6 MB 19.6 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.2/12.6 MB 19.6 MB/s eta 0:00:01
#    ------------------------ --------------- 7.9/12.6 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 11.4 MB/s eta 0:00:01
# ...

# %%
import pandas as pd

# %%
df_premier21 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2122/E0.csv')

# %%
# rename columns

# %%
df_permier21.rename(columns=('FTHG' : 'HOME_GOALS'
# Out:
#   Cell In[14], line 1
#     df_permier21.rename(columns=('FTHG' : 'HOME_GOALS'
#                                         ^
# SyntaxError: invalid syntax

# %%
# reading 1 csv file from the website
